# %%
# Dependencies
import numpy as np
import pandas as pd

# %%
rawdata = pd.read_csv('song_list.csv', encoding='ISO-8859-1')
rawdata=rawdata.drop(['probable_popularity'], axis = 1)
rawdata
# Out:
#                           track               artist  acousticness  \
# 0                    Connection       Henri Salvador        0.0704
# 1                   O Lucky Man       Henri Salvador        0.0464
# 2              We're Going Home       Henri Salvador        0.4110
# 3                   The Dreamer               Chorus        0.0248
# 4                   Paper Money    Leopold Stokowski        0.5050
# ..                          ...                  ...           ...
# 145  A Tisket, A Tasket (Bells)            Jean Davy        0.1950
# 146     Gallop and Switch (6/8)               Chorus        0.9250
# 147   Petite Ballerinas (Vocal)  Marie-Thérèse Orain        0.0326
# 148                    ABC Song               Chorus        0.9830
# 149                Hava Nagilah       Henri Salvador        0.0127
#
#      danceability  energy  instrumentalness  liveness  speechiness    tempo  \
# 0           0.837   0.462           0.01650    0.2400       0.0331  102.048
# ...

# %%
rawdata.to_json('data.js',orient='records')
